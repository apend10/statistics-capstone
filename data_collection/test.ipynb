# %%
import pandas as pd

df = pd.read_csv("fixtures_1992-1993_to_2025-2026.csv")

# %%
df[df["Year"]==2024][df["Home"]=="Arsenal"]
# Out:
# /var/folders/dt/n6z_ll3x7g99tg2r0zlz6_8r0000gn/T/ipykernel_94972/2746987245.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["Year"]==2024][df["Home"]=="Arsenal"]
#        Year    Wk  Day        Date   Time     Home Score             Away  \
# 14048  2024   1.0  Sat  2024-08-17  15:00  Arsenal   2–0           Wolves
# 14065  2024   3.0  Sat  2024-08-31  12:30  Arsenal   1–1         Brighton
# 14101  2024   6.0  Sat  2024-09-28  15:00  Arsenal   4–2   Leicester City
# 14114  2024   7.0  Sat  2024-10-05  15:00  Arsenal   3–1      Southampton
# 14140  2024   9.0  Sun  2024-10-27  16:30  Arsenal   2–2        Liverpool
# 14168  2024  12.0  Sat  2024-11-23  15:00  Arsenal   3–0  Nott'ham Forest
# 14192  2024  14.0  Wed  2024-12-04  20:15  Arsenal   2–0   Manchester Utd
# 14210  2024  16.0  Sat  2024-12-14  15:00  Arsenal   0–0          Everton
# 14238  2024  18.0  Fri  2024-12-27  20:15  Arsenal   1–0     Ipswich Town
# ...

# %%
df = pd.read_csv("transfermarkt_data_normalized.csv")

# %%
df["Team"].unique()
# Out:
# array(['chelsea fc', 'manchester united', 'arsenal fc', 'liverpool fc',
#        'tottenham hotspur', 'newcastle united', 'birmingham city',
#        'middlesbrough fc', 'manchester city', 'southampton fc',
#        'aston villa', 'everton fc', 'blackburn rovers', 'fulham fc',
#        'portsmouth fc', 'bolton wanderers', 'charlton athletic',
#        'west bromwich albion', 'crystal palace', 'norwich city',
#        'west ham united', 'wigan athletic', 'sunderland afc',
#        'sheffield united', 'watford fc', 'reading fc', 'derby county',
#        'hull city', 'stoke city', 'wolverhampton wanderers', 'burnley fc',
#        'blackpool fc', 'queens park rangers', 'swansea city',
#        'cardiff city', 'leicester city', 'afc bournemouth',
#        'brighton & hove albion', 'huddersfield town', 'leeds united',
#        'brentford fc', 'nottingham forest', 'luton town', 'ipswich town'],
#       dtype=object)

# %%
import pandas as pd
df = pd.read_csv("/Users/apendela10/STAT482/statistics-capstone/results/transfermarkt_data_raw.csv")

# %%
df[df["Year"]==2024]["Team"]
# Out:
# 400            manchester city
# 401                 chelsea fc
# 402                 arsenal fc
# 403               liverpool fc
# 404          manchester united
# 405          tottenham hotspur
# 406                aston villa
# 407           newcastle united
# 408     brighton & hove albion
# 409             crystal palace
# 410            afc bournemouth
# 411          nottingham forest
# 412    wolverhampton wanderers
# 413               brentford fc
# 414            west ham united
# 415                 everton fc
# 416                  fulham fc
# 417             southampton fc
# 418               ipswich town
# 419             leicester city
# Name: Team, dtype: object
